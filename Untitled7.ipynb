# %% [markdown]
# <a href="https://colab.research.google.com/github/david090109/proyecto1/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pres = pd.read_csv("/content/ejec_2324_clean_2.csv")

# %%
pres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206691 entries, 0 to 206690
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Código DANE          206691 non-null  int64
#  1   Entidad              206691 non-null  object
#  2   Tipo de Entidad      206691 non-null  object
#  3   Total Recaudo        206691 non-null  int64
#  4   col_1                206691 non-null  object
#  5   col_2                206691 non-null  object
#  6   col_3                206691 non-null  object
#  7   col_4                206691 non-null  object
#  8   col_5                206691 non-null  object
#  9   col_6                206691 non-null  object
#  10  col_7                206691 non-null  object
#  11  col_8                206691 non-null  object
#  12  col_9                206691 non-null  object
#  13  col_10               206691 non-null  object
#  14  Categoría            206479 non-null  float64
# ...

# %%
pres.head()
# Out:
#    Código DANE    Entidad Tipo de Entidad  Total Recaudo     col_1  \
# 0         5000  Antioquia    Departamento     4296815623  INGRESOS
# 1         5000  Antioquia    Departamento   107856005961  INGRESOS
# 2         5000  Antioquia    Departamento   382846271980  INGRESOS
# 3         5000  Antioquia    Departamento    42538474665  INGRESOS
# 4         5000  Antioquia    Departamento    10904213995  INGRESOS
#
#                  col_2                 col_3               col_4  \
# 0  INGRESOS CORRIENTES  INGRESOS TRIBUTARIOS  IMPUESTOS DIRECTOS
# 1  INGRESOS CORRIENTES  INGRESOS TRIBUTARIOS  IMPUESTOS DIRECTOS
# 2  INGRESOS CORRIENTES  INGRESOS TRIBUTARIOS  IMPUESTOS DIRECTOS
# 3  INGRESOS CORRIENTES  INGRESOS TRIBUTARIOS  IMPUESTOS DIRECTOS
# 4  INGRESOS CORRIENTES  INGRESOS TRIBUTARIOS  IMPUESTOS DIRECTOS
#
#                                                col_5  \
# 0               IMPUESTO SOBRE VEHICULOS AUTOMOTORES
# 1               IMPUESTO SOBRE VEHICULOS AUTOMOTORES
# ...

# %%
pres.tail()
# Out:
#         Código DANE                Entidad Tipo de Entidad  Total Recaudo  \
# 206686        27493  Nuevo Belén de Bajirá       Municipio     4197691689
# 206687        27493  Nuevo Belén de Bajirá       Municipio       25573334
# 206688        27493  Nuevo Belén de Bajirá       Municipio       15499616
# 206689        27493  Nuevo Belén de Bajirá       Municipio       25000000
# 206690        27493  Nuevo Belén de Bajirá       Municipio      485911548
#
#            col_1                col_2                                col_3  \
# 206686  INGRESOS  INGRESOS CORRIENTES              INGRESOS NO TRIBUTARIOS
# 206687  INGRESOS  INGRESOS CORRIENTES              INGRESOS NO TRIBUTARIOS
# 206688  INGRESOS  RECURSOS DE CAPITAL             RENDIMIENTOS FINANCIEROS
# 206689  INGRESOS  RECURSOS DE CAPITAL  RECUPERACION DE CARTERA - PRESTAMOS
# 206690  INGRESOS  RECURSOS DE CAPITAL                       RETIROS FONPET
#
#                                                     col_4  \
# ...

# %%
# saeleccionar columnas

# una sola columna

pres["Departamento"]
# Out:
# 0         Antioquia
# 1         Antioquia
# 2         Antioquia
# 3         Antioquia
# 4         Antioquia
#             ...
# 206686        Chocó
# 206687        Chocó
# 206688        Chocó
# 206689        Chocó
# 206690        Chocó
# Name: Departamento, Length: 206691, dtype: object

# %%
pres.columns
# Out:
# Index(['Código DANE', 'Entidad', 'Tipo de Entidad', 'Total Recaudo', 'col_1',
#        'col_2', 'col_3', 'col_4', 'col_5', 'col_6', 'col_7', 'col_8', 'col_9',
#        'col_10', 'Categoría', 'codigo_alt', 'Departamento', 'Año',
#        'clasificacion_ofpuj', 'CodigodDane', 'recaudo_pc', 'recaudo_cons',
#        'recaudo_pc_cons', 'clas_gen', 'clas_gen_2'],
#       dtype='object')

# %%
# Varias columnas

pres[["Departamento", "Entidad"]]
# Out:
#        Departamento                Entidad
# 0         Antioquia              Antioquia
# 1         Antioquia              Antioquia
# 2         Antioquia              Antioquia
# 3         Antioquia              Antioquia
# 4         Antioquia              Antioquia
# ...             ...                    ...
# 206686        Chocó  Nuevo Belén de Bajirá
# 206687        Chocó  Nuevo Belén de Bajirá
# 206688        Chocó  Nuevo Belén de Bajirá
# 206689        Chocó  Nuevo Belén de Bajirá
# 206690        Chocó  Nuevo Belén de Bajirá
#
# [206691 rows x 2 columns]

# %%
df = pres[["codigo_alt", "Entidad", "Tipo de Entidad", "Departamento", "Año",
     "clasificacion_ofpuj", "clas_gen_2", "Total Recaudo"]]

# %%
# Cambiar el nombre de las columnas: snake_case
df = df.rename(columns={"Entidad": "entidad",
                   "Tipo de Entidad": "tipo_entidad",
                   "Departamento": "depto",
                   "Año": "anio",
                   "clas_gen_2": "clas_gen",
                   "Total Recaudo": "total_recaudo"})
# resolver datos nulos de codigo_alt

df.isna().sum()

# verificar los tipos de datos
# Out:
# codigo_alt             0
# entidad                0
# tipo_entidad           0
# depto                  0
# anio                   0
# clasificacion_ofpuj    0
# clas_gen               0
# total_recaudo          0
# dtype: int64

# %%
df[df["codigo_alt"].isna()]
# Out:
#         codigo_alt                entidad Tipo de Entidad  \
# 6137           NaN             San Andrés       Municipio
# 6138           NaN             San Andrés       Municipio
# 6139           NaN             San Andrés       Municipio
# 6140           NaN             San Andrés       Municipio
# 6141           NaN             San Andrés       Municipio
# ...            ...                    ...             ...
# 206686         NaN  Nuevo Belén de Bajirá       Municipio
# 206687         NaN  Nuevo Belén de Bajirá       Municipio
# 206688         NaN  Nuevo Belén de Bajirá       Municipio
# 206689         NaN  Nuevo Belén de Bajirá       Municipio
# 206690         NaN  Nuevo Belén de Bajirá       Municipio
#
#                                            depto  anio  \
# 6137    San Andrés, Providencia y Santa Catalina  2023
# 6138    San Andrés, Providencia y Santa Catalina  2023
# 6139    San Andrés, Providencia y Santa Catalina  2023
# ...

# %%
df.loc[df["entidad"] == "Nuevo Belén de Bajirá", "codigo_alt"] = 27493
df.loc[df["entidad"] == "San Andrés", "codigo_alt"] = 88001

# %%
df.isna().sum()
# Out:
# codigo_alt             0
# entidad                0
# Tipo de Entidad        0
# depto                  0
# anio                   0
# clasificacion_ofpuj    0
# clas_gen               0
# Total Recaudo          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206691 entries, 0 to 206690
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   codigo_alt           206691 non-null  float64
#  1   entidad              206691 non-null  object
#  2   Tipo de Entidad      206691 non-null  object
#  3   depto                206691 non-null  object
#  4   anio                 206691 non-null  int64
#  5   clasificacion_ofpuj  206691 non-null  object
#  6   clas_gen             206691 non-null  object
#  7   Total Recaudo        206691 non-null  int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 12.6+ MB

# %%
df = df.astype({"codigo_alt" : "int"})

# %%
lista = ["Chipaque", "Villavicencio", "Montería"]

# %%
filtro = df[(df["entidad"].isin(lista)) & (df["anio"] == 2024)].reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206691 entries, 0 to 206690
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   codigo_alt           206691 non-null  int64
#  1   entidad              206691 non-null  object
#  2   Tipo de Entidad      206691 non-null  object
#  3   depto                206691 non-null  object
#  4   anio                 206691 non-null  int64
#  5   clasificacion_ofpuj  206691 non-null  object
#  6   clas_gen             206691 non-null  object
#  7   Total Recaudo        206691 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 12.6+ MB

# %%
filtro.groupby(["entidad", "clas_gen"])["total_recaudo"].sum()
# Out:
# entidad        clas_gen
# Chipaque       Ingresos propios          5153055399
#                Recursos de capital       2752405684
#                Transferencias           15214409440
# Montería       Ingresos propios        339720097514
#                Recursos de capital     164816768394
#                Transferencias         1072947978448
# Villavicencio  Ingresos propios        348548463619
#                Recursos de capital     124207333760
#                Transferencias          851449325664
# Name: total_recaudo, dtype: int64

# %%
pres.columns
# Out:
# Index(['Código DANE', 'Entidad', 'Tipo de Entidad', 'Total Recaudo', 'col_1',
#        'col_2', 'col_3', 'col_4', 'col_5', 'col_6', 'col_7', 'col_8', 'col_9',
#        'col_10', 'Categoría', 'codigo_alt', 'Departamento', 'Año',
#        'clasificacion_ofpuj', 'CodigodDane', 'recaudo_pc', 'recaudo_cons',
#        'recaudo_pc_cons', 'clas_gen', 'clas_gen_2'],
#       dtype='object')

# %%
df
# Out:
#         codigo_alt                entidad Tipo de Entidad      depto  anio  \
# 0             5000              Antioquia    Departamento  Antioquia  2023
# 1             5000              Antioquia    Departamento  Antioquia  2023
# 2             5000              Antioquia    Departamento  Antioquia  2023
# 3             5000              Antioquia    Departamento  Antioquia  2023
# 4             5000              Antioquia    Departamento  Antioquia  2023
# ...            ...                    ...             ...        ...   ...
# 206686       27493  Nuevo Belén de Bajirá       Municipio      Chocó  2024
# 206687       27493  Nuevo Belén de Bajirá       Municipio      Chocó  2024
# 206688       27493  Nuevo Belén de Bajirá       Municipio      Chocó  2024
# 206689       27493  Nuevo Belén de Bajirá       Municipio      Chocó  2024
# 206690       27493  Nuevo Belén de Bajirá       Municipio      Chocó  2024
#
#                          clasificacion_ofpuj             clas_gen  \
# ...

# %%
df.columns
# Out:
# Index(['codigo_alt', 'entidad', 'tipo_entidad', 'depto', 'anio',
#        'clasificacion_ofpuj', 'clas_gen', 'total_recaudo'],
#       dtype='object')

# %%
filtro.to_csv("munis.csv", index = False)
